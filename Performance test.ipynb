# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
import math

# %%
df = pd.read_csv("perf.txt", sep = ',', header = None, names=["time_ms", "data_size"])

# %%
df['C'] = np.arange(1,len(df)+1,1)
df['time_ns'] = df['time_ms']/1000

# %%
df.iloc[0:40]
# Out:
#     time_ms  data_size   C  time_ns
# 0      3103        139   1    3.103
# 1      3602        249   2    3.602
# 2      4180        359   3    4.180
# 3      4616        469   4    4.616
# 4      5258        577   5    5.258
# 5      5613        687   6    5.613
# 6      6151        796   7    6.151
# 7      6657        905   8    6.657
# 8      7065       1014   9    7.065
# 9      7778       1123  10    7.778
# 10     8147       1233  11    8.147
# 11     8936       1344  12    8.936
# 12     9382       1455  13    9.382
# 13     9946       1565  14    9.946
# 14    10448       1675  15   10.448
# 15    11007       1785  16   11.007
# 16    11504       1896  17   11.504
# 17    12091       2006  18   12.091
# 18    12708       2116  19   12.708
# 19    13180       2226  20   13.180
# 20    13854       2336  21   13.854
# 21    14220       2447  22   14.220
# 22    14920       2558  23   14.920
# 23    15327       2668  24   15.327
# 24    15705       2778  25   15.705
# ...

# %%
df.plot(x='data_size',
       y='time_ns',
       kind='scatter')

# %%
plt.show()
